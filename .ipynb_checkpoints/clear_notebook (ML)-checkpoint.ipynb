# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.notebook import tqdm
from IPython.display import clear_output
import os
import random
import itertools

# %%
from prophet import Prophet
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split

from sklego.preprocessing import RepeatingBasisFunction

# %% [markdown]
# date_column

# %%
def date_column(x):
    y = x['year']
    m = x['month']
    return pd.Timestamp(y, m, 1)

def date_column_2(x):
    y = x['year']
    m = x['month']
    if y in [2016,2017,2018,2019]:
        return pd.Timestamp(y + 1, m, 1)
    else:
        return pd.Timestamp(y, m, 1)

# %%
train = pd.read_csv(r"New_train.csv")
test = pd.read_csv(r"Test.csv")

# %% [markdown]
# ### Feature engineering

# %%
train['ds'] = train.apply(func = date_column, axis=1)
test['ds'] = test.apply(func = date_column, axis=1)
#train['ds'] = train.apply(func = date_column_2, axis=1)

# %% [markdown]
# **New features**
# - sellin median
# - product_lifecycle_stage

# %%
new_train_list = []
sku_groups = train.groupby(by = 'sku_name')
for sku_name, group in sku_groups:
    group.loc[:,'sellin_median'] = np.median(train[train.sku_name == sku_name].sellin)
    if len(new_train_list)==0:
        new_train_list = [group.copy()]
    else:
        new_train_list.append(group.copy())
train = pd.concat(new_train_list).reset_index(drop=True)

# %%
new_test_list = []
sku_groups = test.groupby(by = 'sku_name')
for sku_name, group in sku_groups:
    try:
        max_date = max(train[train.sku_name == sku_name].ds)
        index = train[(train.sku_name == sku_name) & (train.ds == max_date)].index
        group.loc[:,'product_lifecycle_stage'] = train.loc[index, 'product_lifecycle_stage'].item()
        group.loc[:,'sellin_median'] = np.median(train[train.sku_name == sku_name].sellin)
    except:
        group.loc[:,'product_lifecycle_stage'] = 'U'
        group.loc[:,'sellin_median'] = 30000
    if len(new_test_list)==0:
        new_test_list = [group.copy()]
    else:
        new_test_list.append(group.copy())
test = pd.concat(new_test_list).reset_index(drop=True)

# %% [markdown]
# - sellout general trend

# %%
temp = pd.DataFrame()
for sku_name in test.sku_name.unique():
    sku_temp =  train[train.sku_name == sku_name]
    if sku_temp.shape[0]>=40:
        temp = pd.concat([temp, sku_temp])
temp['y'] = temp['sellout']
prophet = Prophet(yearly_seasonality=3, daily_seasonality=False, weekly_seasonality=False, seasonality_mode = 'multiplicative', n_changepoints = 0)
prophet.fit(temp)
future = prophet.make_future_dataframe(periods=4, freq = 'MS')
forecast = prophet.predict(future)
serie = forecast['yhat']
index = forecast['ds']
a = [1]+[serie[i+1]/serie[i] for i in range(0, len(serie)-1)]
coefs_for_next_observs = pd.Series(data=a, index = index)
# Out:
# C:\Users\egand\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\egand\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)
# C:\Users\egand\anaconda3\lib\site-packages\prophet\forecaster.py:896: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   components = components.append(new_comp)

# %%
train_sku_groups = train.groupby(by = 'sku_name')
cum_coefs_by_sku={}
new_train_list = []

for sku_name, group in train_sku_groups:
    
    #выясняем min date и sellout этой даты, если он равен 0 ты ищем дальше, так как если использовать 0 то все последующие значения будут тоже нулевые
    #если sellout отличный от нуля найти не получилось, то пусть будут везде нули. Хорошо.
    min_date = min(group.ds).asm8.astype('datetime64[M]')
    elem = group[group.ds == min_date].sellout.item()
    if elem == 0:
        other_dates = group.ds[1:]
        for date in other_dates:
            if group[group.ds == date].sellout.item() != 0:
                min_date = date
                elem = group[group.ds == date].sellout.item()
                break
    
    cumulative_coefs =  np.cumprod(coefs_for_next_observs[min_date:])
    cumulative_coefs[0] = 1
    for idx, row in group.iterrows():
        if row['ds']<min_date:
            group.loc[idx,'sellout_general_trend'] = 0
        else:
            group.loc[idx,'sellout_general_trend'] = elem * cumulative_coefs[row['ds']]
        
    cum_coefs_by_sku[sku_name] = (elem, cumulative_coefs)
    if len(new_train_list)==0:
        new_train_list = [group.copy()]
    else:
        new_train_list.append(group.copy())
train = pd.concat(new_train_list).reset_index(drop=True)


test_sku_groups = test.groupby(by = 'sku_name')
new_test_list = []
for sku_name, group in test_sku_groups:
    try: 
        elem, cumulative_coefs = cum_coefs_by_sku[sku_name]
        for idx, row in group.iterrows():
            group.loc[idx,'sellout_general_trend'] = elem * cumulative_coefs[row['ds']]
    except:
        for idx, row in group.iterrows():
            group.loc[idx,'sellout_general_trend'] = 0
    if len(new_test_list)==0:
        new_test_list = [group.copy()]
    else:
        new_test_list.append(group.copy())
test = pd.concat(new_test_list).reset_index(drop=True)

# %% [markdown]
# RFB

# %%
rbf = RepeatingBasisFunction(n_periods=12,
                             #remainder='passthrough',
                             column='month',
                             input_range=(1,12))
rbf.fit(train)
rfb_columns = [f'month_rfb_{i}' for i in range(12)]
rfb_train = pd.DataFrame(index=train.index, data=rbf.transform(train), columns = rfb_columns)
train = pd.concat([train,rfb_train],axis=1)

rfb_test = pd.DataFrame(index=test.index, data=rbf.transform(test), columns = rfb_columns)
test = pd.concat([test,rfb_test],axis=1)

# %%
test.head()
# Out:
#         sku_name  month  year  CAT_GENDER_BOTH  CAT_GENDER_MEN  \
# 0    ABEAHAMASHL     11  2021                0               0
# 1    ABEAHAMASHL     12  2021                0               0
# 2    ABEAHAMASHL      1  2022                0               0
# 3    ABEAHAMASHL      2  2022                0               0
# 4  ABEENNEARMAZZ     11  2021                0               0
#
#    CAT_GENDER_WOMEN         ds product_lifecycle_stage  sellin_median  \
# 0                 1 2021-11-01                       W       252237.0
# 1                 1 2021-12-01                       W       252237.0
# 2                 1 2022-01-01                       W       252237.0
# 3                 1 2022-02-01                       W       252237.0
# 4                 1 2021-11-01                       W       219821.0
#
#    sellout_general_trend
# 0          101202.583856
# 1          115292.731368
# 2           67958.969958
# 3           25758.615822
# 4           10650.961414

# %% [markdown]
# ### catboost

# %% [markdown]
# **Попытка 1**
# - Добавить product_lifecycle_stage (дополнить тестовые записи последним lifecycle_stage из трейна)

# %% [markdown]
# Результаты:
# - Ошибка на кросс валидации 185-190к
# - Ошибка на тесте 233к

# %% [markdown]
# **Попытка 2**
# - Добавить product_lifecycle_stage (дополнить тестовые записи последним lifecycle_stage из трейна)
# - Добавить sellin_median (медианы товаров)

# %% [markdown]
# Результаты:
# - модель: lr 0.1, n_est 1000, l2 1, depth 10
# - Ошибка на кросс валидации 125-140к
# - Ошибка на тесте 174к (172к если взять модуль предсказаний)

# %% [markdown]
# **Попытка 3**
# - Добавить product_lifecycle_stage (дополнить тестовые записи последним lifecycle_stage из трейна)
# - Добавить sellin_median (медианы товаров)
# - Закодировать month radial basis functions (RFB)

# %% [markdown]
# Результаты:
# - модель: n_estimators = 1000, lr=0.1, l2 = 6, depth = 8
# - Ошибка на кросс валидации 125-135к
# - Ошибка на тесте 199k

# %% [markdown]
# **Попытка 4**
# - Добавить product_lifecycle_stage (дополнить тестовые записи последним lifecycle_stage из трейна)
# - Добавить sellin_median (медианы товаров)
# - Добавить общий тренд sellout постороенный на тестовых товарах Prophet

# %% [markdown]
# Результаты:
# - Ошибка на кросс валидации 130-135к
# - Ошибка на тесте 182к

# %%
y_train = train['sellin']
train = train.drop(columns = 'sellin')

# %%
#попытка 1
#features = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','month','year','product_lifecycle_stage']
#попытка 2
#features = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','month','year','product_lifecycle_stage','sellin_median']
#попытка 3
#features = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','year','product_lifecycle_stage','sellin_median'] + rfb_columns
#попытка 4
features = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','month','year','product_lifecycle_stage','sellin_median','sellout_general_trend']

#попытка 1,2,4
cat_cols = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','month','year','product_lifecycle_stage']
#попытка 3
#cat_cols = ['CAT_GENDER_BOTH','CAT_GENDER_MEN','CAT_GENDER_WOMEN','year','product_lifecycle_stage']

# %%
model = CatBoostRegressor(early_stopping_rounds=250,
                          grow_policy = 'Depthwise',
                          loss_function='MAE',
                          cat_features= cat_cols,
                          verbose=False)
params = {'l2_leaf_reg':[1,3,6],
          'learning_rate': [0.01, 0.1, 0.4],
          'depth':[6,8,10],
          'n_estimators':range(250, 1001, 250)
         }

# %%
grid_search_res = model.grid_search(params, train[features], y_train, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# bestTest = 145380.661
# bestIteration = 249
#
#
# bestTest = 133135.713
# bestIteration = 249
#
#
# bestTest = 134786.0365
# bestIteration = 212
#
#
# bestTest = 145300.8374
# bestIteration = 249
#
#
# bestTest = 133334.3435
# bestIteration = 244
#
#
# bestTest = 134805.5367
# bestIteration = 245
#
#
# bestTest = 145186.6171
# bestIteration = 249
#
#
# bestTest = 132547.9887
# bestIteration = 249
#
#
# bestTest = 133867.8395
# bestIteration = 234
#
#
# bestTest = 138763.61
# bestIteration = 499
#
#
# bestTest = 132012.958
# bestIteration = 496
#
#
# bestTest = 134171.2583
# bestIteration = 452
#
#
# bestTest = 138478.034
# bestIteration = 499
#
#
# bestTest = 132462.5333
# bestIteration = 493
#
#
# bestTest = 134509.1944
# bestIteration = 382
#
#
# bestTest = 138222.8866
# bestIteration = 499
#
#
# bestTest = 131394.3387
# bestIteration = 498
#
#
# bestTest = 132892.6279
# bestIteration = 492
#
#
# bestTest = 136463.4763
# bestIteration = 749
#
#
# bestTest = 131572.2778
# bestIteration = 747
#
#
# bestTest = 133944.0409
# bestIteration = 540
#
#
# bestTest = 136552.8683
# bestIteration = 749
#
#
# bestTest = 131999.0018
# bestIteration = 748
#
#
# bestTest = 134396.7998
# bestIteration = 749
#
#
# bestTest = 136423.0905
# bestIteration = 749
#
#
# bestTest = 130973.2174
# bestIteration = 744
#
#
# bestTest = 132465.5915
# bestIteration = 689
#
#
# bestTest = 135263.9428
# bestIteration = 999
#
#
# bestTest = 131249.9699
# bestIteration = 972
#
#
# bestTest = 133806.9765
# bestIteration = 997
#
#
# bestTest = 135524.9203
# bestIteration = 999
#
#
# bestTest = 131530.0179
# bestIteration = 999
#
#
# bestTest = 134174.1252
# bestIteration = 965
#
#
# bestTest = 135254.2905
# bestIteration = 999
#
#
# bestTest = 130702.7644
# bestIteration = 995
#
#
# bestTest = 132271.546
# bestIteration = 898
#
#
# bestTest = 142512.8601
# bestIteration = 249
#
#
# bestTest = 130917.1997
# bestIteration = 249
#
#
# bestTest = 132931.2338
# bestIteration = 190
#
#
# bestTest = 142593.5287
# bestIteration = 249
#
#
# bestTest = 130639.3961
# bestIteration = 249
#
#
# bestTest = 132302.4734
# bestIteration = 179
#
#
# bestTest = 142174.5889
# bestIteration = 249
#
#
# bestTest = 131363.3598
# bestIteration = 248
#
#
# bestTest = 131540.6876
# bestIteration = 64
#
#
# bestTest = 135660.913
# bestIteration = 499
#
#
# bestTest = 130024.7963
# bestIteration = 498
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132931.2338
# bestIteration = 190
#
#
# bestTest = 135717.6933
# bestIteration = 499
#
#
# bestTest = 130077.8718
# bestIteration = 478
#
#
# bestTest = 132182.1473
# bestIteration = 267
#
#
# bestTest = 135284.7402
# bestIteration = 499
#
#
# bestTest = 130525.8016
# bestIteration = 497
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 131540.6876
# bestIteration = 64
#
#
# bestTest = 134041.9631
# bestIteration = 749
#
#
# bestTest = 129912.8504
# bestIteration = 596
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132931.2338
# bestIteration = 190
#
#
# bestTest = 133947.0701
# bestIteration = 749
#
#
# bestTest = 129822.0017
# bestIteration = 600
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132182.1473
# bestIteration = 267
#
#
# bestTest = 133694.3125
# bestIteration = 749
#
#
# bestTest = 130188.2336
# bestIteration = 748
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 131540.6876
# bestIteration = 64
#
#
# bestTest = 133134.1306
# bestIteration = 997
#
#
# bestTest = 129779.7782
# bestIteration = 995
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132931.2338
# bestIteration = 190
#
#
# bestTest = 132947.3201
# bestIteration = 998
#
#
# bestTest = 129702.4346
# bestIteration = 948
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132182.1473
# bestIteration = 267
#
#
# bestTest = 132887.6009
# bestIteration = 999
#
#
# bestTest = 130082.3957
# bestIteration = 915
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 131540.6876
# bestIteration = 64
#
#
# bestTest = 139984.9507
# bestIteration = 249
#
#
# bestTest = 130235.5894
# bestIteration = 239
#
#
# bestTest = 133313.1599
# bestIteration = 105
#
#
# bestTest = 140060.5634
# bestIteration = 249
#
#
# bestTest = 130001.6407
# bestIteration = 245
#
#
# bestTest = 133460.7935
# bestIteration = 82
#
#
# bestTest = 140010.3477
# bestIteration = 249
#
#
# bestTest = 130075.1018
# bestIteration = 249
#
#
# bestTest = 132439.9049
# bestIteration = 73
#
#
# bestTest = 133426.0937
# bestIteration = 499
#
#
# bestTest = 129582.2897
# bestIteration = 497
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133313.1599
# bestIteration = 105
#
#
# bestTest = 133454.2188
# bestIteration = 499
#
#
# bestTest = 129897.9076
# bestIteration = 490
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133460.7935
# bestIteration = 82
#
#
# bestTest = 133342.1273
# bestIteration = 499
#
#
# bestTest = 129540.5339
# bestIteration = 447
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132439.9049
# bestIteration = 73
#
#
# bestTest = 131957.7495
# bestIteration = 748
#
#
# bestTest = 129456.4829
# bestIteration = 578
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133313.1599
# bestIteration = 105
#
#
# bestTest = 131946.3441
# bestIteration = 749
#
#
# bestTest = 129633.1973
# bestIteration = 722
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133460.7935
# bestIteration = 82
#
#
# bestTest = 131916.7253
# bestIteration = 749
#
#
# bestTest = 129249.0481
# bestIteration = 654
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132439.9049
# bestIteration = 73
#
#
# bestTest = 131187.0919
# bestIteration = 999
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 129456.4829
# bestIteration = 578
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133313.1599
# bestIteration = 105
#
#
# bestTest = 131156.4449
# bestIteration = 999
#
#
# bestTest = 129558.0687
# bestIteration = 981
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 133460.7935
# bestIteration = 82
#
#
# bestTest = 131150.8499
# bestIteration = 999
#
#
# bestTest = 129203.691
# bestIteration = 852
#
# Stopped by overfitting detector  (250 iterations wait)
#
# bestTest = 132439.9049
# bestIteration = 73
#
# Stopped by overfitting detector  (250 iterations wait)

# %%
grid_search_res['params']
# Out:
# {'depth': 10, 'l2_leaf_reg': 6, 'iterations': 1000, 'learning_rate': 0.1}

# %%
model_ = CatBoostRegressor(early_stopping_rounds=250,
                           depth=10,
                           n_estimators = 1000,
                           learning_rate = 0.1,
                           l2_leaf_reg = 6,
                          grow_policy = 'Depthwise',
                          loss_function='MAE',
                          cat_features= cat_cols,
                          verbose=False)
model_.fit(train[features], y_train)

# %%
importances = model_.feature_importances_

feature_importances = pd.Series(importances, index=features).sort_values(ascending=False)

plt.figure(figsize=(10, 5))
fig, ax = plt.subplots()
feature_importances.plot.bar(ax=ax)
ax.set_title("Feature importances using")
ax.set_ylabel("Mean decrease in impurity")
# Out:
# Text(0, 0.5, 'Mean decrease in impurity')

# %%
test['pred'] = abs(model_.predict(test[features]))

# %%
lst = []
columns=["Item_ID", "Target"]
for idx, row in test.iterrows():
    lst.append([row['sku_name']+'_'+str(row['month'])+'_'+str(row['year']), row['pred']])
sub = pd.DataFrame(data=lst, columns = columns)

# %%
sub.to_csv(os.getcwd()+'\submission 64 (abs preds); catboost = n_estimators = 1000, lr=0.1, l2 = 6, depth = 10; cv mae = 130-135k; features = lifecycle_stage, gender, month, year, sellin_median, sellout_general_trend.csv',index=False)

# %%
sub
# Out:
#                      Item_ID         Target
# 0        ABEAHAMASHL_11_2021    3487.064547
# 1        ABEAHAMASHL_12_2021    3297.387774
# 2         ABEAHAMASHL_1_2022  241968.045160
# 3         ABEAHAMASHL_2_2022  180558.550050
# 4      ABEENNEARMAZZ_11_2021    5718.152812
# ...                      ...            ...
# 1523     YOSHRENECARL_2_2022  505140.033411
# 1524  YOSHTLYNYOSHZZ_11_2021   81550.275482
# 1525  YOSHTLYNYOSHZZ_12_2021  139101.721854
# 1526   YOSHTLYNYOSHZZ_1_2022  329320.922006
# 1527   YOSHTLYNYOSHZZ_2_2022  544455.716647
#
# [1528 rows x 2 columns]
